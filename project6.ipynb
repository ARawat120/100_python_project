# %%
# What are Functions?
# Function is the important part in coding while we deal with big project to reduce the complexity and for easy understanding..

# %%
# Defining and Calling Function
def fun():
    print("Function is display")
fun()
# Out:
# Function is display

# %%
# Function Parameters and Argument
def fun(x,y):
    print("sum of two number is : ",x+y)
fun(3,4)
# Out:
# sum of two number is :  7

# %%
# Return Statement
def remainder(a,b):
    return a%b
value = remainder(4,3)
print(value)
# Out:
# 1
