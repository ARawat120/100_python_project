# %%
print("Hello Python ! My ancient time is good...")

# %%
print("The number is ", 4)
print("2 + 2 = ", 2 + 2)

# %%
value =19
print(f"My age is {value}")

# %%
born_year = int(input("Enter the your born year..",))
print(born_year)

# %%
#   Project: Welcome Message Generator





name,age,hobby = input("What is  your name ? ",),int(input("Enter your age.." ,)),input("what is your hobby ? ",)

print("*******---- Welcome to my new project ----******")
print("Hello ",name," !!!!")
print("///Your Hobby ",hobby," so nice/// ")
print("your age is ",age)
