# %%
# Variables : They are like a containers where we store an data or value.
# variables are start with small alphabet and contains number,alphabet,underscore.
name = "Rawat"
age = 19
print(name,age)

# %%
# Data Types(string,integer,boolean,float)

name = "raj"
result = 85
percentage = 75.9
is_student = True

print(name,result,is_student,percentage)
print(type(name),type(result),type(is_student),type(percentage))

# %%
# Type Conversion

num= 19004050432
print(float(num))

# %%
# String Formatting

rollno = 203945685
print(f"my rollno is {rollno}")

# %%
;# Personalized Greeting Program

name = input("What is your Name ?",)
age = int(input("Enter your age",))
colour = input("What is your Favourite colour!! ",)

print("------- Personalised Greeting ---------\n"
      f"Hello {name} , Your age is {age}!!! \n"
      f"{colour} is your favourite colour //",)
